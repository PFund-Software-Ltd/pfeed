# %% [markdown]
# # Partition Pruning

# %% [markdown]
# `pfeed` supports partition pruning for parquet files.

# %%
import pfeed as pe

# get the configured data path
config = pe.get_config()
data_path = config.data_path

# %% [markdown]
# ## Using PyArrow

# %%
import pyarrow.dataset as ds

dataset = ds.dataset(data_path, format="parquet", partitioning="hive")
# filter the dataset by product type
dataset.filter(
    (ds.field("product_type") == "PERP")
).to_table().to_pandas()

# %% [markdown]
# ## Using Polars

# %%
import polars as pl

lf = pl.scan_parquet(f'{data_path}/**/*.parquet', hive_partitioning=True)
# filter by product type, need to cast to string first using lazyframe
df = lf.filter(pl.col("product_type").cast(pl.String) == "PERP").collect()
df
# Out:
# shape: (5_760, 18)
# ┌──────────────┬────────────┬───────────────┬─────────┬───┬──────────────┬──────┬───────┬─────┐
# │ date         ┆ resolution ┆ product       ┆ symbol  ┆ … ┆ product_type ┆ year ┆ month ┆ day │
# │ ---          ┆ ---        ┆ ---           ┆ ---     ┆   ┆ ---          ┆ ---  ┆ ---   ┆ --- │
# │ datetime[μs] ┆ str        ┆ str           ┆ str     ┆   ┆ str          ┆ i64  ┆ i64   ┆ i64 │
# ╞══════════════╪════════════╪═══════════════╪═════════╪═══╪══════════════╪══════╪═══════╪═════╡
# │ 2025-01-01   ┆ 1m         ┆ BTC_USDT_PERP ┆ BTCUSDT ┆ … ┆ PERP         ┆ 2025 ┆ 1     ┆ 1   │
# │ 00:00:00     ┆            ┆               ┆         ┆   ┆              ┆      ┆       ┆     │
# │ 2025-01-01   ┆ 1m         ┆ BTC_USDT_PERP ┆ BTCUSDT ┆ … ┆ PERP         ┆ 2025 ┆ 1     ┆ 1   │
# │ 00:01:00     ┆            ┆               ┆         ┆   ┆              ┆      ┆       ┆     │
# │ 2025-01-01   ┆ 1m         ┆ BTC_USDT_PERP ┆ BTCUSDT ┆ … ┆ PERP         ┆ 2025 ┆ 1     ┆ 1   │
# │ 00:02:00     ┆            ┆               ┆         ┆   ┆              ┆      ┆       ┆     │
# │ 2025-01-01   ┆ 1m         ┆ BTC_USDT_PERP ┆ BTCUSDT ┆ … ┆ PERP         ┆ 2025 ┆ 1     ┆ 1   │
# │ 00:03:00     ┆            ┆               ┆         ┆   ┆              ┆      ┆       ┆     │
# │ 2025-01-01   ┆ 1m         ┆ BTC_USDT_PERP ┆ BTCUSDT ┆ … ┆ PERP         ┆ 2025 ┆ 1     ┆ 1   │
# │ 00:04:00     ┆            ┆               ┆         ┆   ┆              ┆      ┆       ┆     │
# │ …            ┆ …          ┆ …             ┆ …       ┆ … ┆ …            ┆ …    ┆ …     ┆ …   │
# │ 2025-02-02   ┆ 1m         ┆ BTC_USDT_PERP ┆ BTCUSDT ┆ … ┆ PERP         ┆ 2025 ┆ 2     ┆ 2   │
# │ 23:55:00     ┆            ┆               ┆         ┆   ┆              ┆      ┆       ┆     │
# │ 2025-02-02   ┆ 1m         ┆ BTC_USDT_PERP ┆ BTCUSDT ┆ … ┆ PERP         ┆ 2025 ┆ 2     ┆ 2   │
# │ 23:56:00     ┆            ┆               ┆         ┆   ┆              ┆      ┆       ┆     │
# │ 2025-02-02   ┆ 1m         ┆ BTC_USDT_PERP ┆ BTCUSDT ┆ … ┆ PERP         ┆ 2025 ┆ 2     ┆ 2   │
# │ 23:57:00     ┆            ┆               ┆         ┆   ┆              ┆      ┆       ┆     │
# │ 2025-02-02   ┆ 1m         ┆ BTC_USDT_PERP ┆ BTCUSDT ┆ … ┆ PERP         ┆ 2025 ┆ 2     ┆ 2   │
# │ 23:58:00     ┆            ┆               ┆         ┆   ┆              ┆      ┆       ┆     │
# │ 2025-02-02   ┆ 1m         ┆ BTC_USDT_PERP ┆ BTCUSDT ┆ … ┆ PERP         ┆ 2025 ┆ 2     ┆ 2   │
# │ 23:59:00     ┆            ┆               ┆         ┆   ┆              ┆      ┆       ┆     │
# └──────────────┴────────────┴───────────────┴─────────┴───┴──────────────┴──────┴───────┴─────┘

# %% [markdown]
# ## Using DuckDB

# %%
import duckdb

query = f"""
SELECT * FROM '{data_path}/**/*.parquet'
WHERE volume > 100
"""
df = duckdb.sql(query).df()
df
# Out:
#                    date resolution        product   symbol     open     high  \
# 0   2025-01-01 00:10:00         1m  BTC_USDT_PERP  BTCUSDT  93574.1  93602.4
# 1   2025-01-01 00:19:00         1m  BTC_USDT_PERP  BTCUSDT  93785.8  93791.3
# 2   2025-01-01 00:47:00         1m  BTC_USDT_PERP  BTCUSDT  93850.0  93934.2
# 3   2025-01-01 00:50:00         1m  BTC_USDT_PERP  BTCUSDT  93929.0  94051.0
# 4   2025-01-01 00:54:00         1m  BTC_USDT_PERP  BTCUSDT  94150.0  94278.7
# ..                  ...        ...            ...      ...      ...      ...
# 760 2025-02-02 23:40:00         1m  BTC_USDT_PERP  BTCUSDT  97501.8  97590.0
# 761 2025-02-02 23:42:00         1m  BTC_USDT_PERP  BTCUSDT  97421.4  97479.6
# 762 2025-02-02 23:44:00         1m  BTC_USDT_PERP  BTCUSDT  97320.1  97367.5
# 763 2025-02-02 23:46:00         1m  BTC_USDT_PERP  BTCUSDT  97459.0  97628.1
# 764 2025-02-02 23:48:00         1m  BTC_USDT_PERP  BTCUSDT  97650.2  97696.0
#
#          low    close   volume  data_domain data_layer data_origin  \
# 0    93494.1  93500.0  114.178  market_data    cleaned       BYBIT
# 1    93755.0  93762.1  130.847  market_data    cleaned       BYBIT
# 2    93845.0  93909.6  142.830  market_data    cleaned       BYBIT
# 3    93914.9  94037.9  148.347  market_data    cleaned       BYBIT
# 4    94145.4  94205.0  265.202  market_data    cleaned       BYBIT
# ..       ...      ...      ...          ...        ...         ...
# 760  97300.4  97487.3  131.160  market_data    cleaned       BYBIT
# 761  97291.1  97434.9  107.282  market_data    cleaned       BYBIT
# 762  97202.6  97288.1  156.376  market_data    cleaned       BYBIT
# 763  97400.0  97581.7  119.197  market_data    cleaned       BYBIT
# 764  97515.6  97547.3  133.217  market_data    cleaned       BYBIT
#
#     data_source day       env month product_type  year
# 0         BYBIT  01  BACKTEST    01         PERP  2025
# 1         BYBIT  01  BACKTEST    01         PERP  2025
# 2         BYBIT  01  BACKTEST    01         PERP  2025
# 3         BYBIT  01  BACKTEST    01         PERP  2025
# 4         BYBIT  01  BACKTEST    01         PERP  2025
# ..          ...  ..       ...   ...          ...   ...
# 760       BYBIT  02  BACKTEST    02         PERP  2025
# 761       BYBIT  02  BACKTEST    02         PERP  2025
# 762       BYBIT  02  BACKTEST    02         PERP  2025
# 763       BYBIT  02  BACKTEST    02         PERP  2025
# 764       BYBIT  02  BACKTEST    02         PERP  2025
#
# [765 rows x 18 columns]
